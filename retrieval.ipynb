# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma
from huggingface_hub import login
import torch
from sentence_transformers import SentenceTransformer
import transformers
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers import pipeline
from langchain_community.llms.huggingface_pipeline import HuggingFacePipeline 
from langchain.chains.conversational_retrieval.base import ConversationalRetrievalChain
from langchain.memory import ConversationBufferMemory
from langchain_community.embeddings import OpenAIEmbeddings
from langchain_community.chat_models import ChatOpenAI
import os, sys, argparse, time
import pandas as pd
from tqdm import tqdm
from itertools import islice

# %%
from dotenv import dotenv_values
from huggingface_hub import login
venv = dotenv_values('.env')
login(token=venv["HF_TOKEN"], add_to_git_credential=True)

MODEL_EMBED = 'sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2'
# Out:
# Token has not been saved to git credential helper.
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.

# %%
# def create_vector_store(train_file, collection_name, vectordb):
#     resource = train_file

#     chunksize = 800000
#     max_batch_size = 40000
#     cnt = 0
#     vectorstore = None
#     init = 0
#     for chunk in pd.read_csv(resource, chunksize=chunksize):
#         cnt += 1
#         documents = []
#         # ids = []
#         metadatas = []
#         for _, row in tqdm(chunk.iterrows(), total=chunk.shape[0], desc=f"Processing CSV {cnt}"):
#             ct = row['text']
#             if '"' in ct:
#                 ct = ct.replace('"', '')
#             if r'\n' in ct:
#                 ct = ct.replace(r'\n', '')
#             if r'/' in ct:
#                 ct = ct.replace(r'/', '')
#             dic = f""""Context": {ct}"""
#             documents.append(dic)
#             # ids.append(str(row['cid'][1:-1]))
#             metadatas.append({"cid": row['cid']})
#         # print(documents[0], ids[0], metadatas[0])
        
#         device = 'cuda' if torch.cuda.is_available() else 'cpu'
#         model_kwargs = {'device': device, 'trust_remote_code': True}
#         cache_dir = r"../.cache"

#         embeddings = HuggingFaceEmbeddings(
#             model_name=MODEL_EMBED,
#             cache_folder=cache_dir,
#             model_kwargs=model_kwargs,
#             show_progress=True,
#         )
#         # if (len(documents) == len(ids)) and (len(ids) == len(metadatas)):
#         #     print(f"Number of documents: {len(documents)}")
#         #     time.sleep(1)

#         if init == 0:
#             print("Initializing ChromaDB")
#             vectorstore = Chroma.from_texts(
#                 texts=documents,
#                 # ids=ids,
#                 metadatas=metadatas,
#                 embedding=embeddings,
#                 persist_directory=vectordb,
#                 collection_name=collection_name,
#             )
#             init += 1
#         else:
#             vectorstore.add_texts(
#                 texts=documents,
#                 # ids=ids,
#                 metadatas=metadatas,
#                 embedding=embeddings,
#             )
#     print(f"Collection {collection_name} created successfully in {vectordb}")

# %%
def create_vector_store_from_dataset(dataset_name, collection_name, vectordb, MODEL_EMBED):
    """
    Tạo vector store từ Hugging Face Dataset.

    Args:
        dataset_name: Tên của dataset trên Hugging Face Hub hoặc đường dẫn đến dataset cục bộ.
        collection_name: Tên của collection trong vectordb.
        vectordb: Đường dẫn đến thư mục lưu trữ vectordb.
        MODEL_EMBED: Tên của mô hình embedding.

    """
    from datasets import load_dataset
    dataset = load_dataset(dataset_name)
    dataset = dataset['train']
    
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    model_kwargs = {'device': device} #'trust_remote_code': True} Bỏ trust_remote_code nếu không cần
    cache_dir = r"../.cache"

    embeddings = HuggingFaceEmbeddings(
        model_name=MODEL_EMBED,
        cache_folder=cache_dir,
        model_kwargs=model_kwargs,
        show_progress=True,
    )

    vectorstore = None
    chunk_size = 20000
    
    for i in range(0, len(dataset), chunk_size):
        # Lặp qua tất cả các split (train, test, validation)
        documents = []
        metadatas = []
        chunk = islice(dataset, i, i + chunk_size)
        for row in tqdm(chunk, desc=f"Processing split {chunk}"):
            text = row['context']
            if isinstance(text, list):
                 text = " ".join(text)  # Nối list thành string nếu cần
            # Tiền xử lý text nếu cần
            if '"' in text:
                text = text.replace('"', '')
            if r'\n' in text:
                text = text.replace(r'\n', '')
            if r'/' in text:
                text = text.replace(r'/', '')


            documents.append(text)
            metadatas.append({"cid": row['cid']})

        if vectorstore is None:
            print("Initializing ChromaDB")
            vectorstore = Chroma.from_texts(
                texts=documents,
                metadatas=metadatas,
                embedding=embeddings,
                persist_directory=vectordb,
                collection_name=collection_name,
            )
        else:
            vectorstore.add_texts(
                texts=documents,
                metadatas=metadatas,
                embedding=embeddings,
            )

    print(f"Collection {collection_name} created successfully in {vectordb}")

# %%
# def chatbot_response(content, collection_name, vectordb, index):
#     # model_name = 'meta-llama/Llama-3.2-1B-Instruct' if args.model_name == 'llama' else args.model_name
#     cache_dir = r"../.cache"
# #     tokenizer = AutoTokenizer.from_pretrained(model_name)
# #     model = AutoModelForCausalLM.from_pretrained(
# #         model_name,
# #         device_map="cuda",
# #         cache_dir=cache_dir,
# #         torch_dtype=torch.bfloat16,)

# #     pipe = pipeline(
# #         'text-generation',
# #         model=model,
# #         tokenizer=tokenizer,
# #         device_map="auto",
# #         max_new_tokens=600
# #         )
# #     llm = HuggingFacePipeline(
# #         pipeline=pipe,
# #         model_kwargs={'temperature': 0.6, 'top_p': 0.4},
# #     )

#     device = 'cuda' if torch.cuda.is_available() else 'cpu'
#     model_kwargs = {'device': device, 'trust_remote_code': True}
#     embeddings = HuggingFaceEmbeddings(
#         model_name=MODEL_EMBED,
#         cache_folder=cache_dir,
#         model_kwargs=model_kwargs,
#         show_progress=True,
#         )

#     vectorstore = Chroma(
#         embedding_function=embeddings,
#         persist_directory=vectordb,
#         collection_name=collection_name
#     )
#     # memory = ConversationBufferMemory(memory_key='chat_history', return_messages=True)
#     # qa = ConversationalRetrievalChain.from_llm(llm=llm, 
#     #                                            retriever=vectorstore.as_retriever(search_kwargs={'k':10}),
#     #                                            verbose=False, memory=memory)
#     # chat = qa({'question': f'{content}'})
#     # print(chat['answer'])
    
#     # Retrieve the top 10 contexts and their corresponding cids
#     results = vectorstore.as_retriever(search_kwargs={'k': 10}).get_relevant_documents(content)
#     cids = [doc.metadata['cid'] for doc in results]  # Assuming 'qid' is what you meant by cid
#     # cids = [doc.id for doc in results]
#     print(f"Top 10 cids related to the question: {index} ", *cids)
#     more_cid = ""
#     for i in cids:
#         more_cid += f" {i}"
#     string_result = f"{index} {more_cid}"
#     print(string_result)
#     return string_result

# %%
corpus_file = r"NaverLegal/corpus.csv"
dataset_name = "Zappu/Legal-vn"
vectordb_path = r"Docs_Legal_T1"
collection_name = "DocsLegalT1"

# %%
# create_vector_store_from_dataset(dataset_name, collection_name, vectordb_path, MODEL_EMBED)

# %%
# create_vector_store(corpus_file, collection_name, vectordb_path)

# %%
# test_file = r"NaverLegal/public_test.csv"
# test_df = pd.read_csv(test_file)

# %%
def chatbot_response_dataset(content, collection_name, vectordb, index, ):
    # model_name = 'meta-llama/Llama-3.2-1B-Instruct' if args.model_name == 'llama' else args.model_name
    cache_dir = r"../.cache"
#     tokenizer = AutoTokenizer.from_pretrained(model_name)
#     model = AutoModelForCausalLM.from_pretrained(
#         model_name,
#         device_map="cuda",
#         cache_dir=cache_dir,
#         torch_dtype=torch.bfloat16,)

#     pipe = pipeline(
#         'text-generation',
#         model=model,
#         tokenizer=tokenizer,
#         device_map="auto",
#         max_new_tokens=600
#         )
#     llm = HuggingFacePipeline(
#         pipeline=pipe,
#         model_kwargs={'temperature': 0.6, 'top_p': 0.4},
#     )

    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    model_kwargs = {'device': device, 'trust_remote_code': True}
    embeddings = HuggingFaceEmbeddings(
        model_name=MODEL_EMBED,
        cache_folder=cache_dir,
        model_kwargs=model_kwargs,
        # show_progress=True,
        # resume_download,
        )

    vectorstore = Chroma(
        embedding_function=embeddings,
        persist_directory=vectordb,
        collection_name=collection_name
    )
    # memory = ConversationBufferMemory(memory_key='chat_history', return_messages=True)
    # qa = ConversationalRetrievalChain.from_llm(llm=llm, 
    #                                            retriever=vectorstore.as_retriever(search_kwargs={'k':10}),
    #                                            verbose=False, memory=memory)
    # chat = qa({'question': f'{content}'})
    # print(chat['answer'])
    
    # Retrieve the top 10 contexts and their corresponding cids
    results = vectorstore.as_retriever(search_kwargs={'k': 10}).get_relevant_documents(content)
    cids = [doc.metadata['cid'] for doc in results]  # Assuming 'qid' is what you meant by cid
    # cids = [doc.id for doc in results]
    # print(f"Top 10 cids related to the question: {index} ", *cids)
    more_cid = ""
    for i in cids:
        more_cid += f" {i[1:-1]}"
    string_result = f"{index} {more_cid}"
    # print(string_result)
    return string_result

# %%
# with open('predict.txt', 'w') as f:
#     for _, row in tqdm(test_df.iterrows(), total=10000, desc="Search rows"):
#         content = row['question']
#         qid = row['qid']
#         response = chatbot_response(content, collection_name, vectordb_path, qid)
#         f.write(response + '\n')

# %%
from datasets import load_dataset
with open('predict2.txt', 'w') as f:
    dataset = load_dataset(dataset_name)
    dataset = dataset['train']
    dataset.select(range(10))
    for row in tqdm(dataset, desc=f"Processing split {dataset.split}"):
        content = row['question']
        qid = row['qid']
        response = chatbot_response_dataset(content, collection_name, vectordb_path, qid)
        f.write(response + '\n')
# Out:
# Processing split train:   0%|          | 0/79456 [00:00<?, ?it/s]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   0%|          | 115/79456 [07:28<83:00:09,  3.77s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   0%|          | 116/79456 [07:31<78:51:29,  3.58s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   0%|          | 117/79456 [07:35<80:46:06,  3.66s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   0%|          | 118/79456 [07:38<81:05:53,  3.68s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   0%|          | 119/79456 [07:42<81:22:18,  3.69s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   0%|          | 120/79456 [07:46<82:36:08,  3.75s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   0%|          | 121/79456 [07:50<83:25:11,  3.79s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ...
#   warnings.warn(
# Processing split train:   1%|          | 469/79456 [29:55<87:42:38,  4.00s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 470/79456 [29:59<91:47:29,  4.18s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 471/79456 [30:03<89:11:20,  4.07s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 472/79456 [30:07<86:39:18,  3.95s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 473/79456 [30:11<89:39:24,  4.09s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 474/79456 [30:15<89:31:36,  4.08s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 475/79456 [30:20<91:57:11,  4.19s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 476/79456 [30:24<95:05:33,  4.33s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 477/79456 [30:28<94:26:21,  4.30s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 478/79456 [30:33<96:49:14,  4.41s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 479/79456 [30:37<96:05:21,  4.38s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 480/79456 [30:42<96:58:26,  4.42s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 481/79456 [30:47<98:08:54,  4.47s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 482/79456 [30:51<96:35:42,  4.40s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 483/79456 [30:55<97:28:49,  4.44s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 484/79456 [31:00<97:06:06,  4.43s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 485/79456 [31:04<93:00:38,  4.24s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 486/79456 [31:07<90:20:46,  4.12s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 487/79456 [31:11<87:17:23,  3.98s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 488/79456 [31:15<88:41:50,  4.04s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 489/79456 [31:19<87:07:01,  3.97s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 490/79456 [31:23<89:43:08,  4.09s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 491/79456 [31:28<95:18:28,  4.35s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 492/79456 [31:32<92:38:18,  4.22s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 493/79456 [31:36<92:42:05,  4.23s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 494/79456 [31:41<93:30:57,  4.26s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 495/79456 [31:46<97:29:16,  4.44s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 496/79456 [31:50<98:19:06,  4.48s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 497/79456 [31:54<95:24:10,  4.35s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 498/79456 [31:59<97:29:44,  4.45s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 499/79456 [32:03<95:01:59,  4.33s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f6110bf8520>>
# Traceback (most recent call last):
#   File "/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# Processing split train:   1%|          | 500/79456 [32:07<92:57:53,  4.24s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 501/79456 [32:12<95:33:27,  4.36s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 502/79456 [32:17<98:48:15,  4.51s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 503/79456 [32:21<98:17:49,  4.48s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 504/79456 [32:25<97:14:55,  4.43s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 505/79456 [32:30<101:05:49,  4.61s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 506/79456 [32:35<104:43:34,  4.78s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 507/79456 [32:40<102:13:18,  4.66s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing split train:   1%|          | 508/79456 [32:45<103:20:46,  4.71s/it]/home/studio-lab-user/.conda/envs/rag/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
# !pip install ipython==8.24.0 ipykernel==6.29.4 ipywidgets==7.8.1 \
jupyter-client==7.4.9 jupyter_core==5.7.2 jupyter_server==2.14.0 \
jupyterlab==3.6.7 nbclient==0.10.0 nbconvert==7.16.3 nbformat==5.10.4 \
notebook==6.5.7 qtconsole==5.5.1 traitlets==5.14.3
